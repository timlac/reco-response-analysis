# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from nexa_py_sentimotion_mapper.sentimotion_mapper import Mapper

Mapper._load_data_if_needed()

# %%
path = "../data/appraisal/export_appraisal.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    user_id                                          survey_id  \
# 0  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 1  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 2  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 3  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 4  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
#
#    survey_item_index          filename  has_reply               emotion_1  \
# 0                  0  A200_int_v_3.mp4          1      interest_curiosity
# 1                  1  A102_exc_v_3.mp4          1  excitement_expectation
# 2                  2  A102_fea_p_2.mp4          1                    fear
# 3                  3  A102_amu_v_3.mp4          1               amusement
# 4                  4  A207_pea_v_2.mp4          1   peacefulness_serenity
#
#   video_id  mix  emotion_1_id  emotion_2_id  intensity_level  \
# 0     A200    0            29           100              3.0
# 1     A102    0            36           100              3.0
# 2     A102    0            10           100              2.0
# 3     A102    0            13           100              3.0
# 4     A207    0            25           100              2.0
#
#    reply_dim_Novelty  reply_dim_Pleasantness  reply_dim_Goal conduciveness  \
# 0                  1                       4                             4
# 1                  1                       5                             5
# 2                  3                       1                             1
# 3                  2                       4                             4
# 4                  1                       2                             2
#
#    reply_dim_Urgency  reply_dim_Power  reply_dim_Norm compatibility
# 0                  1                3                             3
# 1                  1                3                             5
# 2                  2                2                             1
# 3                  2                3                             4
# 4                  2                2                             2

# %%
df['emotion'] = df['emotion_1_id'].map(Mapper.get_emotion_from_id)
df.head()
# Out:
#    user_id                                          survey_id  \
# 0  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 1  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 2  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 3  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
# 4  default  1d1439eb990b9fbdc99bf899dc7a7f9cb61a9a404e5677...
#
#    survey_item_index          filename  has_reply               emotion_1  \
# 0                  0  A200_int_v_3.mp4          1      interest_curiosity
# 1                  1  A102_exc_v_3.mp4          1  excitement_expectation
# 2                  2  A102_fea_p_2.mp4          1                    fear
# 3                  3  A102_amu_v_3.mp4          1               amusement
# 4                  4  A207_pea_v_2.mp4          1   peacefulness_serenity
#
#   video_id  mix  emotion_1_id  emotion_2_id  intensity_level  \
# 0     A200    0            29           100              3.0
# 1     A102    0            36           100              3.0
# 2     A102    0            10           100              2.0
# 3     A102    0            13           100              3.0
# 4     A207    0            25           100              2.0
#
#    reply_dim_Novelty  reply_dim_Pleasantness  reply_dim_Goal conduciveness  \
# 0                  1                       4                             4
# 1                  1                       5                             5
# 2                  3                       1                             1
# 3                  2                       4                             4
# 4                  1                       2                             2
#
#    reply_dim_Urgency  reply_dim_Power  reply_dim_Norm compatibility  \
# 0                  1                3                             3
# 1                  1                3                             5
# 2                  2                2                             1
# 3                  2                3                             4
# 4                  2                2                             2
#
#                   emotion
# 0      interest_curiosity
# 1  excitement_expectation
# 2                    fear
# 3               amusement
# 4   peacefulness_serenity

# %%
list(df["emotion"])
# Out:
# ['interest_curiosity',
#  'excitement_expectation',
#  'fear',
#  'amusement',
#  'peacefulness_serenity',
#  'distress_pain',
#  'tenderness',
#  'happiness_joy',
#  'excitement_expectation',
#  'being_moved',
#  'sexual_lust',
#  'interest_curiosity',
#  'schadenfreude',
#  'positive_surprise',
#  'disgust',
#  'awe',
#  'relief',
#  'rejection',
#  'embarrassment',
#  'sadness',
#  'anxiety',
#  'nostalgia',
#  'inspiration',
#  'envy',
#  'contempt',
#  'relief',
#  'peacefulness_serenity',
#  'nostalgia',
#  'boredom',
#  'confusion',
#  'positive_surprise',
#  'guilt',
#  'sadness',
#  'pride',
#  'regret',
#  'doubt',
#  'amusement',
#  'neutral',
#  'pride',
#  'anger',
#  'fear',
#  'sexual_lust',
#  'gratitude',
#  'schadenfreude',
#  'hope',
#  'disappointment',
#  'disappointment',
#  'contempt',
#  'sensory_pleasure',
#  'awe',
#  'concentration',
#  'hope',
#  'elevation_rejoicing',
#  'shame',
#  'being_moved',
#  'triumph_achievement',
#  'tenderness',
#  'gratitude',
#  'inspiration',
#  'embarrassment',
#  'guilt',
#  'satisfaction_contentment',
#  'elevation_rejoicing',
#  'disgust',
#  'negative_surprise',
#  'regret',
#  'admiration',
#  'sensory_pleasure',
#  'neutral',
#  'shame',
#  'sarcasm',
#  'concentration',
#  'anger',
#  'determination',
#  'anxiety',
#  'triumph_achievement',
#  'rejection',
#  'satisfaction_contentment',
#  'envy',
#  'doubt',
#  'happiness_joy',
#  'distress_pain',
#  'boredom',
#  'negative_surprise',
#  'admiration',
#  'sarcasm',
#  'determination',
#  'confusion',
#  'doubt',
#  'shame',
#  'doubt',
#  'gratitude',
#  'inspiration',
#  'shame',
#  'contempt',
#  'sexual_lust',
#  'regret',
#  'positive_surprise',
#  'disgust',
#  'elevation_rejoicing',
#  'excitement_expectation',
#  'anxiety',
#  'being_moved',
#  'triumph_achievement',
#  'envy',
#  'triumph_achievement',
#  'happiness_joy',
#  'inspiration',
#  'nostalgia',
#  'neutral',
#  'concentration',
#  'nostalgia',
#  'interest_curiosity',
#  'sarcasm',
#  'awe',
#  'admiration',
#  'regret',
#  'confusion',
#  'disgust',
#  'embarrassment',
#  'fear',
#  'gratitude',
#  'disappointment',
#  'sarcasm',
#  'guilt',
#  'admiration',
#  'peacefulness_serenity',
#  'schadenfreude',
#  'rejection',
#  'sadness',
#  'amusement',
#  'hope',
#  'embarrassment',
#  'anger',
#  'excitement_expectation',
#  'distress_pain',
#  'happiness_joy',
#  'schadenfreude',
#  'awe',
#  'tenderness',
#  'tenderness',
#  'guilt',
#  'being_moved',
#  'neutral',
#  'negative_surprise',
#  'anxiety',
#  'rejection',
#  'hope',
#  'elevation_rejoicing',
#  'sensory_pleasure',
#  'relief',
#  'sadness',
#  'boredom',
#  'confusion',
#  'embarrassment',
#  'negative_surprise',
#  'awe',
#  'excitement_expectation',
#  'schadenfreude',
#  'elevation_rejoicing',
#  'tenderness',
#  'sensory_pleasure',
#  'admiration',
#  'confusion',
#  'happiness_joy',
#  'inspiration',
#  'tenderness',
#  'determination',
#  'envy',
#  'gratitude',
#  'admiration',
#  'pride',
#  'satisfaction_contentment',
#  'sarcasm',
#  'shame',
#  'anger',
#  'awe',
#  'guilt',
#  'anger',
#  'rejection',
#  'sarcasm',
#  'fear',
#  'hope',
#  'contempt',
#  'triumph_achievement',
#  'boredom',
#  'disappointment',
#  'anxiety',
#  'fear',
#  'distress_pain',
#  'pride',
#  'sadness',
#  'schadenfreude',
#  'being_moved',
#  'relief',
#  'distress_pain',
#  'sensory_pleasure',
#  'negative_surprise',
#  'positive_surprise',
#  'inspiration',
#  'rejection',
#  'envy',
#  'doubt',
#  'neutral',
#  'anxiety',
#  'confusion',
#  'sexual_lust',
#  'disgust',
#  'nostalgia',
#  'elevation_rejoicing',
#  'nostalgia',
#  'gratitude',
#  'satisfaction_contentment',
#  'concentration',
#  'neutral',
#  'relief',
#  'contempt',
#  'shame',
#  'boredom',
#  'amusement',
#  'peacefulness_serenity',
#  'interest_curiosity',
#  'embarrassment',
#  'positive_surprise',
#  'being_moved',
#  'doubt',
#  'regret',
#  'peacefulness_serenity',
#  'determination',
#  'triumph_achievement',
#  'sexual_lust',
#  'disappointment',
#  'disgust',
#  'guilt',
#  'excitement_expectation',
#  'sadness',
#  'happiness_joy',
#  'amusement',
#  'interest_curiosity',
#  'regret',
#  'hope',
#  'concentration',
#  'fear',
#  'fear',
#  'neutral',
#  'hope',
#  'peacefulness_serenity',
#  'happiness_joy',
#  'peacefulness_serenity',
#  'sexual_lust',
#  'nostalgia',
#  'elevation_rejoicing',
#  'rejection',
#  'hope',
#  'sensory_pleasure',
#  'negative_surprise',
#  'relief',
#  'amusement',
#  'schadenfreude',
#  'envy',
#  'being_moved',
#  'interest_curiosity',
#  'gratitude',
#  'awe',
#  'distress_pain',
#  'embarrassment',
#  'shame',
#  'envy',
#  'inspiration',
#  'admiration',
#  'determination',
#  'disgust',
#  'pride',
#  'contempt',
#  'awe',
#  'excitement_expectation',
#  'amusement',
#  'triumph_achievement',
#  'boredom',
#  'guilt',
#  'admiration',
#  'relief',
#  'disgust',
#  'elevation_rejoicing',
#  'satisfaction_contentment',
#  'anger',
#  'disappointment',
#  'boredom',
#  'regret',
#  'tenderness',
#  'determination',
#  'rejection',
#  'anxiety',
#  'neutral',
#  'concentration',
#  'happiness_joy',
#  'sarcasm',
#  'guilt',
#  'shame',
#  'pride',
#  'distress_pain',
#  'tenderness',
#  'concentration',
#  'contempt',
#  'being_moved',
#  'anger',
#  'sadness',
#  'sexual_lust',
#  'nostalgia',
#  'gratitude',
#  'satisfaction_contentment',
#  'disappointment',
#  'doubt',
#  'confusion',
#  'negative_surprise',
#  'schadenfreude',
#  'doubt',
#  'inspiration',
#  'regret',
#  'sadness',
#  'positive_surprise',
#  'embarrassment',
#  'excitement_expectation',
#  'positive_surprise',
#  'interest_curiosity',
#  'triumph_achievement',
#  'sensory_pleasure',
#  'anxiety',
#  'confusion',
#  'sarcasm',
#  'sadness',
#  'disgust',
#  'relief',
#  'regret',
#  'confusion',
#  'inspiration',
#  'satisfaction_contentment',
#  'fear',
#  'nostalgia',
#  'disappointment',
#  'being_moved',
#  'guilt',
#  'happiness_joy',
#  'pride',
#  'schadenfreude',
#  'confusion',
#  'guilt',
#  'disgust',
#  'doubt',
#  'sensory_pleasure',
#  'gratitude',
#  'shame',
#  'anxiety',
#  'neutral',
#  'envy',
#  'neutral',
#  'tenderness',
#  'excitement_expectation',
#  'concentration',
#  'hope',
#  'positive_surprise',
#  'contempt',
#  'excitement_expectation',
#  'amusement',
#  'embarrassment',
#  'sadness',
#  'elevation_rejoicing',
#  'relief',
#  'pride',
#  'distress_pain',
#  'doubt',
#  'concentration',
#  'elevation_rejoicing',
#  'interest_curiosity',
#  'distress_pain',
#  'awe',
#  'admiration',
#  'sensory_pleasure',
#  'rejection',
#  'sexual_lust',
#  'determination',
#  'being_moved',
#  'happiness_joy',
#  'negative_surprise',
#  'disappointment',
#  'anger',
#  'boredom',
#  'awe',
#  'boredom',
#  'interest_curiosity',
#  'contempt',
#  'tenderness',
#  'positive_surprise',
#  'schadenfreude',
#  'satisfaction_contentment',
#  'anxiety',
#  'nostalgia',
#  'envy',
#  'fear',
#  'anger',
#  'sarcasm',
#  'shame',
#  'peacefulness_serenity',
#  'negative_surprise',
#  'embarrassment',
#  'rejection',
#  'regret',
#  'triumph_achievement',
#  'admiration',
#  'hope',
#  'sexual_lust',
#  'triumph_achievement',
#  'gratitude',
#  'peacefulness_serenity',
#  'amusement',
#  'inspiration',
#  'determination',
#  'sarcasm',
#  'sarcasm',
#  'envy',
#  'anxiety',
#  'embarrassment',
#  'elevation_rejoicing',
#  'regret',
#  'pride',
#  'admiration',
#  'disappointment',
#  'sadness',
#  'boredom',
#  'sensory_pleasure',
#  'triumph_achievement',
#  'tenderness',
#  'positive_surprise',
#  'embarrassment',
#  'hope',
#  'confusion',
#  'schadenfreude',
#  'admiration',
#  'inspiration',
#  'pride',
#  'nostalgia',
#  'fear',
#  'distress_pain',
#  'triumph_achievement',
#  'excitement_expectation',
#  'determination',
#  'negative_surprise',
#  'contempt',
#  'sadness',
#  'envy',
#  'concentration',
#  'relief',
#  'disappointment',
#  'shame',
#  'tenderness',
#  'anxiety',
#  'doubt',
#  'awe',
#  'anger',
#  'doubt',
#  'neutral',
#  'positive_surprise',
#  'satisfaction_contentment',
#  'amusement',
#  'satisfaction_contentment',
#  'guilt',
#  'neutral',
#  'sexual_lust',
#  'being_moved',
#  'amusement',
#  'peacefulness_serenity',
#  'rejection',
#  'gratitude',
#  'hope',
#  'guilt',
#  'schadenfreude',
#  'peacefulness_serenity',
#  'being_moved',
#  'contempt',
#  'interest_curiosity',
#  'confusion',
#  'disgust',
#  'interest_curiosity',
#  'sensory_pleasure',
#  'inspiration',
#  'regret',
#  'gratitude',
#  'anger',
#  'concentration',
#  'sexual_lust',
#  'distress_pain',
#  'elevation_rejoicing',
#  'negative_surprise',
#  'sarcasm',
#  'shame',
#  'fear',
#  'happiness_joy',
#  'happiness_joy',
#  'boredom',
#  'relief',
#  'disgust',
#  'awe',
#  'nostalgia',
#  'excitement_expectation',
#  'determination',
#  'rejection',
#  'relief',
#  'sensory_pleasure',
#  'satisfaction_contentment',
#  'anger',
#  'negative_surprise',
#  'sadness',
#  'inspiration',
#  'elevation_rejoicing',
#  'disgust',
#  'disgust',
#  'peacefulness_serenity',
#  'boredom',
#  'sarcasm',
#  'shame',
#  'inspiration',
#  'fear',
#  'tenderness',
#  'distress_pain',
#  'neutral',
#  'pride',
#  'contempt',
#  'excitement_expectation',
#  'amusement',
#  'admiration',
#  'embarrassment',
#  'fear',
#  'gratitude',
#  'pride',
#  'positive_surprise',
#  'anxiety',
#  'positive_surprise',
#  'tenderness',
#  'anxiety',
#  'admiration',
#  'awe',
#  'envy',
#  'elevation_rejoicing',
#  'anger',
#  'happiness_joy',
#  'gratitude',
#  'triumph_achievement',
#  'shame',
#  'concentration',
#  'regret',
#  'happiness_joy',
#  'guilt',
#  'schadenfreude',
#  'sensory_pleasure',
#  'sarcasm',
#  'satisfaction_contentment',
#  'confusion',
#  'relief',
#  'disappointment',
#  'being_moved',
#  'hope',
#  'embarrassment',
#  'neutral',
#  'rejection',
#  'disappointment',
#  'distress_pain',
#  'envy',
#  'rejection',
#  'triumph_achievement',
#  'boredom',
#  'negative_surprise',
#  'being_moved',
#  'concentration',
#  'confusion',
#  'determination',
#  'interest_curiosity',
#  'hope',
#  'doubt',
#  'guilt',
#  'schadenfreude',
#  'contempt',
#  'doubt',
#  'interest_curiosity',
#  'nostalgia',
#  'regret',
#  'nostalgia',
#  'amusement',
#  'awe',
#  'sexual_lust',
#  'sadness',
#  'determination',
#  'peacefulness_serenity',
#  'excitement_expectation',
#  'sexual_lust',
#  'admiration',
#  'sensory_pleasure',
#  'envy',
#  'anxiety',
#  'disgust',
#  'sexual_lust',
#  'disappointment',
#  'doubt',
#  'negative_surprise',
#  'nostalgia',
#  'awe',
#  'schadenfreude',
#  'positive_surprise',
#  'relief',
#  'nostalgia',
#  'sadness',
#  'determination',
#  'relief',
#  'peacefulness_serenity',
#  'concentration',
#  'neutral',
#  'elevation_rejoicing',
#  'inspiration',
#  'gratitude',
#  'guilt',
#  'negative_surprise',
#  'gratitude',
#  'doubt',
#  'tenderness',
#  'sadness',
#  'shame',
#  'fear',
#  'shame',
#  'contempt',
#  'happiness_joy',
#  'sarcasm',
#  'sensory_pleasure',
#  'rejection',
#  'disappointment',
#  'boredom',
#  'fear',
#  'excitement_expectation',
#  'excitement_expectation',
#  'awe',
#  'being_moved',
#  'tenderness',
#  'boredom',
#  'embarrassment',
#  'sexual_lust',
#  'elevation_rejoicing',
#  'inspiration',
#  'triumph_achievement',
#  'distress_pain',
#  'guilt',
#  'anger',
#  'satisfaction_contentment',
#  'sarcasm',
#  'rejection',
#  'anger',
#  'hope',
#  'embarrassment',
#  'happiness_joy',
#  'hope',
#  'amusement',
#  'being_moved',
#  'pride',
#  'distress_pain',
#  'triumph_achievement',
#  'confusion',
#  'satisfaction_contentment',
#  'interest_curiosity',
#  'schadenfreude',
#  'positive_surprise',
#  'amusement',
#  'regret',
#  'admiration',
#  'regret',
#  'peacefulness_serenity',
#  'neutral',
#  'interest_curiosity',
#  'concentration',
#  'confusion',
#  'pride',
#  'disgust',
#  'contempt',
#  'determination',
#  'envy',
#  'anxiety',
#  'nostalgia',
#  'positive_surprise',
#  'regret',
#  'admiration',
#  'disgust',
#  'elevation_rejoicing',
#  'concentration',
#  'happiness_joy',
#  'peacefulness_serenity',
#  'hope',
#  'rejection',
#  'interest_curiosity',
#  'pride',
#  'contempt',
#  'disappointment',
#  'amusement',
#  'contempt',
#  'sexual_lust',
#  'amusement',
#  'boredom',
#  'tenderness',
#  'admiration',
#  'envy',
#  'inspiration',
#  'disgust',
#  'regret',
#  'sadness',
#  'determination',
#  'schadenfreude',
#  'gratitude',
#  'sadness',
#  'peacefulness_serenity',
#  'being_moved',
#  'shame',
#  'triumph_achievement',
#  'determination',
#  'disappointment',
#  'embarrassment',
#  'negative_surprise',
#  'fear',
#  'excitement_expectation',
#  'anxiety',
#  'inspiration',
#  'happiness_joy',
#  'doubt',
#  'anger',
#  'satisfaction_contentment',
#  'hope',
#  'confusion',
#  'relief',
#  'neutral',
#  'shame',
#  'schadenfreude',
#  'neutral',
#  'awe',
#  'concentration',
#  'sarcasm',
#  'distress_pain',
#  'boredom',
#  'being_moved',
#  'sarcasm',
#  'embarrassment',
#  'fear',
#  'satisfaction_contentment',
#  'doubt',
#  'confusion',
#  'guilt',
#  'envy',
#  'interest_curiosity',
#  'excitement_expectation',
#  'positive_surprise',
#  'relief',
#  'anger',
#  'guilt',
#  'negative_surprise',
#  'gratitude',
#  'tenderness',
#  'elevation_rejoicing',
#  'anxiety',
#  'triumph_achievement',
#  'nostalgia',
#  'rejection',
#  'sensory_pleasure',
#  'sensory_pleasure',
#  'distress_pain',
#  'pride',
#  'sexual_lust',
#  'awe']

# %%
df.describe()
# Out:
#        survey_item_index  has_reply    mix  emotion_1_id  emotion_2_id  \
# count         770.000000      770.0  770.0    770.000000         770.0
# mean           42.557143        1.0    0.0     21.523377         100.0
# std            25.126727        0.0    0.0     12.723430           0.0
# min             0.000000        1.0    0.0      0.000000         100.0
# 25%            21.000000        1.0    0.0     10.250000         100.0
# 50%            42.000000        1.0    0.0     21.500000         100.0
# 75%            64.000000        1.0    0.0     33.000000         100.0
# max            87.000000        1.0    0.0     43.000000         100.0
#
#        intensity_level  reply_dim_Novelty  reply_dim_Pleasantness  \
# count       752.000000         770.000000              770.000000
# mean          2.571809           2.564935                2.703896
# std           0.495146           1.317706                1.448953
# min           2.000000           1.000000                1.000000
# 25%           2.000000           1.000000                1.000000
# 50%           3.000000           2.000000                2.000000
# 75%           3.000000           4.000000                4.000000
# max           3.000000           5.000000                5.000000
#
#        reply_dim_Goal conduciveness  reply_dim_Urgency  reply_dim_Power  \
# count                    770.000000         770.000000       770.000000
# mean                       2.725974           2.445455         2.627273
# std                        1.533832           1.285211         1.250242
# min                        1.000000           1.000000         1.000000
# 25%                        1.000000           1.000000         2.000000
# 50%                        2.500000           2.000000         3.000000
# 75%                        4.000000           3.000000         4.000000
# max                        5.000000           5.000000         5.000000
#
#        reply_dim_Norm compatibility
# count                    770.000000
# mean                       2.989610
# std                        1.429722
# min                        1.000000
# 25%                        2.000000
# 50%                        3.000000
# 75%                        4.000000
# max                        5.000000

# %%
# List of dimensions to plot
dimensions = [
    'reply_dim_Novelty', 'reply_dim_Pleasantness',
    'reply_dim_Goal conduciveness', 'reply_dim_Urgency',
    'reply_dim_Power', 'reply_dim_Norm compatibility'
]

# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a violin plot for each dimension
for dim in dimensions:
    plt.figure(figsize=(24, 6))
    sns.violinplot(x='emotion', y=dim, data=df, inner="point")
    plt.title(f'Distribution of {dim} by Emotion')
    plt.xlabel('Emotion')
    plt.ylabel(dim)
    plt.xticks(rotation=90)  # Rotate emotion labels for better readability
    plt.show()

# %%
selected_emotions = ['fear', 'happiness_joy']

filtered_df = df[df['emotion'].isin(selected_emotions)]

counts = filtered_df.groupby(['emotion', 'reply_dim_Novelty', 'reply_dim_Pleasantness']).size().reset_index(name='counts')

jitter_strength = 0.05  # Adjust based on your dataset and visual needs

counts['jittered_novelty'] = counts['reply_dim_Novelty'] + np.random.uniform(-jitter_strength, jitter_strength, size=len(counts))
counts['jittered_pleasantness'] = counts['reply_dim_Pleasantness'] + np.random.uniform(-jitter_strength, jitter_strength, size=len(counts))

plt.figure(figsize=(10, 6))

# Plot using Seaborn. The size argument scales point sizes according to the 'counts' column.
sns.scatterplot(data=counts, x='jittered_novelty', y='jittered_pleasantness', hue='emotion', size='counts', sizes=(20, 200), alpha=0.6, legend='full')

plt.title('Distribution of Ratings by Emotion with Jitter')
plt.xlabel('Reply Dimension Novelty (with jitter)')
plt.ylabel('Reply Dimension Pleasantness (with jitter)')

# Adjust the legend to outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
